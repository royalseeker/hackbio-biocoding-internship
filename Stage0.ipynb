# %% [markdown]
# <a href="https://colab.research.google.com/github/royalseeker/hackbio-biocoding-internship/blob/main/Stage0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
team_threonine = {

    "Aparna Padmanabhan": {

        "slack_username": "Aparna",

        "email": "aparna2118@gmail.com",

        "hobby": "Badminton",

        "country": "India",

        "discipline": "Molecular biology",

        "programming_language": "Python"

    },

    "Maher Tantouch": {

        "slack_username": "maher",

        "email": "maher.tantouch@gmail.com",

        "hobby": "Cinema",

        "country": "Tunisian",

        "discipline": "Biology",

        "programming_language": "Python"

    },

    "Eseohe Ugbeva": {

        "slack_username": "eseohe",

        "email": "eseoheugbeva@gmail.com",

        "hobby": "Baking",

        "country": "Nigeria",

        "discipline": "Biochemistry",

        "programming_language": "Python"

    },

    "Muhsinah": {

        "slack_username": "Muhsinah",

        "email": "muhsinahabdulwasiu@gmail.com",

        "hobby": "Traveling",

        "country": "Nigeria",

        "discipline": "Pharmacy",

        "programming_language": "R"

    },

    "Rayan Ahmed": {

        "slack_username": "royal.ram16",

        "email": "royal.ram16@gmail.com",

        "hobby": "Wanderlust",

        "country": "UK",

        "discipline": "Bioinformatics",

        "programming_language": "Python"

    }


}


print(
    "HackBio Internship: Stage0 \n" + "\n"

    "Team Threonine Members:\n" + "\n"

    "Name: Aparna Padmanabhan\n"

    f"Slack Username: {team_threonine['Aparna Padmanabhan']['slack_username']}\n"

    f"Email: {team_threonine['Aparna Padmanabhan']['email']}\n"

    f"Hobby: {team_threonine['Aparna Padmanabhan']['hobby']}\n"

    f"Country: {team_threonine['Aparna Padmanabhan']['country']}\n"

    f"Discipline: {team_threonine['Aparna Padmanabhan']['discipline']}\n"

    f"Preferred Programming Language: {team_threonine['Aparna Padmanabhan']['programming_language']}\n\n"



    "Name: Maher Tantouch\n"

    f"Slack Username: {team_threonine['Maher Tantouch']['slack_username']}\n"

    f"Email: {team_threonine['Maher Tantouch']['email']}\n"

    f"Hobby: {team_threonine['Maher Tantouch']['hobby']}\n"

    f"Country: {team_threonine['Maher Tantouch']['country']}\n"

    f"Discipline: {team_threonine['Maher Tantouch']['discipline']}\n"

    f"Preferred Programming Language: {team_threonine['Maher Tantouch']['programming_language']}\n\n"



    "Name: Eseohe Ugbeva\n"

    f"Slack Username: {team_threonine['Eseohe Ugbeva']['slack_username']}\n"

    f"Email: {team_threonine['Eseohe Ugbeva']['email']}\n"

    f"Hobby: {team_threonine['Eseohe Ugbeva']['hobby']}\n"

    f"Country: {team_threonine['Eseohe Ugbeva']['country']}\n"

    f"Discipline: {team_threonine['Eseohe Ugbeva']['discipline']}\n"

    f"Preferred Programming Language: {team_threonine['Eseohe Ugbeva']['programming_language']}\n\n"



    "Name: Muhsinah\n"

    f"Slack Username: {team_threonine['Muhsinah']['slack_username']}\n"

    f"Email: {team_threonine['Muhsinah']['email']}\n"

    f"Hobby: {team_threonine['Muhsinah']['hobby']}\n"

    f"Country: {team_threonine['Muhsinah']['country']}\n"

    f"Discipline: {team_threonine['Muhsinah']['discipline']}\n"

    f"Preferred Programming Language: {team_threonine['Muhsinah']['programming_language']}\n\n"



    "Name: Rayan Ahmed\n"

    f"Slack Username: {team_threonine['Rayan Ahmed']['slack_username']}\n"

    f"Email: {team_threonine['Rayan Ahmed']['email']}\n"

    f"Hobby: {team_threonine['Rayan Ahmed']['hobby']}\n"

    f"Country: {team_threonine['Rayan Ahmed']['country']}\n"

    f"Discipline: {team_threonine['Rayan Ahmed']['discipline']}\n"

    f"Preferred Programming Language: {team_threonine['Rayan Ahmed']['programming_language']}\n\n"
#Github: https://github.com/royalseeker


)
# Out:
# HackBio Internship: Stage0
#
# Team Threonine Members:
#
# Name: Aparna Padmanabhan
# Slack Username: Aparna
# Email: aparna2118@gmail.com
# Hobby: Badminton
# Country: India
# Discipline: Molecular biology
# Preferred Programming Language: Python
#
# Name: Maher Tantouch
# Slack Username: maher
# Email: maher.tantouch@gmail.com
# Hobby: Cinema
# Country: Tunisian
# Discipline: Biology
# Preferred Programming Language: Python
#
# Name: Eseohe Ugbeva
# Slack Username: eseohe
# Email: eseoheugbeva@gmail.com
# Hobby: Baking
# Country: Nigeria
# Discipline: Biochemistry
# Preferred Programming Language: Python
#
# Name: Muhsinah
# Slack Username: Muhsinah
# Email: muhsinahabdulwasiu@gmail.com
# Hobby: Traveling
# Country: Nigeria
# Discipline: Pharmacy
# Preferred Programming Language: R
#
# Name: Rayan Ahmed
# Slack Username: royal.ram16
# Email: royal.ram16@gmail.com
# Hobby: Wanderlust
# Country: UK
# Discipline: Bioinformatics
# Preferred Programming Language: Python

# %%
# !pip install --upgrade git+https://github.com/PyGithub/PyGithub.git@v1.59.0
# Out:
# ...
#   Cloning https://github.com/PyGithub/PyGithub.git (to revision v1.59.0) to /tmp/pip-req-build-4dhskfs6
#   Running command git clone --filter=blob:none --quiet https://github.com/PyGithub/PyGithub.git /tmp/pip-req-build-4dhskfs6
#   Running command git checkout -q 14ae2cad4ceeefe9a0f70916af03f0a2017ca213
#   Resolved https://github.com/PyGithub/PyGithub.git to commit 14ae2cad4ceeefe9a0f70916af03f0a2017ca213
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 11.1 MB/s eta 0:00:00
# ...
#   Created wheel for PyGithub: filename=PyGithub-1.59.0-py3-none-any.whl size=342106 sha256=b0bfe9b1d90276bebee6eb019517088f82ac916c31a2e95089b269b9be6072e5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g2c5vmh3/wheels/f8/b6/2d/a1db316e3b858f877a3731fd714a76ea021e8d93ba03f23e9e
# Successfully built PyGithub
# ...

# %%
from getpass import getpass
from google.colab import userdata
import os


# Request user input for GitHub personal access token
github_token = userdata.get('github')
os.environ['GITHUB_TOKEN'] = github_token  # Store token in an environment variable for security

# %%
# Get the latest commit SHA for the file
contents = repo.get_contents("stage-zero/Stage0.ipynb", ref="main")
latest_sha = contents.sha

# Update the file with new content
with open('/content/drive/MyDrive/G SYNC/Hackbiointernship/Stage0.ipynb', 'rb') as f:
  updated_content = f.read()

# Update the file on GitHub
repo.update_file(contents.path, "Update Stage0.ipynb", base64.b64encode(updated_content).decode('utf-8'), latest_sha, branch="main")
# Out:
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# <ipython-input-20-1171b689d803> in <cell line: 0>()
#       4
#       5 # Update the file on GitHub
# ----> 6 repo.update_file(contents.path, "Update Stage0.ipynb", base64.b64encode(updated_content).decode('utf-8'), latest_sha, branch="main")
#
# /usr/local/lib/python3.11/dist-packages/github/Repository.py in update_file(self, path, message, content, sha, branch, committer, author)
#    2508             put_parameters["committer"] = committer._identity
#    2509
# -> 2510         headers, data = self._requester.requestJsonAndCheck(
#    2511             "PUT",
#    2512             f"{self.url}/contents/{urllib.parse.quote(path)}",
#
# /usr/local/lib/python3.11/dist-packages/github/Requester.py in requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     440         input: Optional[Any] = None,
# ...
